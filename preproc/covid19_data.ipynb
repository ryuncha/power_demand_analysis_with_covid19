# %%
import pandas as pd
import datetime

import database_info

# %%
engine, conn = database_info.getServerEngine()

# %%
df = pd.read_csv('../raw/covid19/covid19.csv')

# %%
df = df[df['countriesAndTerritories'].isin(['South_Korea','United_Kingdom','Japan','Cases_on_an_international_conveyance_Japan','France',''])]

# %%
df
# Out:
#           dateRep  day  month  year  cases  deaths  \
# 3646   10/03/2020   10      3  2020     -9       1
# 3647   02/03/2020    2      3  2020      0       0
# 3648   01/03/2020    1      3  2020      0       0
# 3649   29/02/2020   29      2  2020      0       2
# 3650   28/02/2020   28      2  2020      0       0
# ...           ...  ...    ...   ...    ...     ...
# 19584  04/01/2020    4      1  2020      0       0
# 19585  03/01/2020    3      1  2020      0       0
# 19586  02/01/2020    2      1  2020      0       0
# 19587  01/01/2020    1      1  2020      0       0
# 19588  31/12/2019   31     12  2019      0       0
#
#                           countriesAndTerritories     geoId  \
# 3646   Cases_on_an_international_conveyance_Japan  JPG11668
# 3647   Cases_on_an_international_conveyance_Japan  JPG11668
# 3648   Cases_on_an_international_conveyance_Japan  JPG11668
# 3649   Cases_on_an_international_conveyance_Japan  JPG11668
# ...

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#         dateRep  day  month  year  cases  deaths  \
# 0    10/03/2020   10      3  2020     -9       1
# 1    02/03/2020    2      3  2020      0       0
# 2    01/03/2020    1      3  2020      0       0
# 3    29/02/2020   29      2  2020      0       2
# 4    28/02/2020   28      2  2020      0       0
# ..          ...  ...    ...   ...    ...     ...
# 671  04/01/2020    4      1  2020      0       0
# 672  03/01/2020    3      1  2020      0       0
# 673  02/01/2020    2      1  2020      0       0
# 674  01/01/2020    1      1  2020      0       0
# 675  31/12/2019   31     12  2019      0       0
#
#                         countriesAndTerritories     geoId  \
# 0    Cases_on_an_international_conveyance_Japan  JPG11668
# 1    Cases_on_an_international_conveyance_Japan  JPG11668
# 2    Cases_on_an_international_conveyance_Japan  JPG11668
# 3    Cases_on_an_international_conveyance_Japan  JPG11668
# 4    Cases_on_an_international_conveyance_Japan  JPG11668
# ...

# %%
df['LoadDay'] = df['dateRep'].apply(lambda x:datetime.datetime.strptime(x, '%d/%m/%Y'))

# %%
ndf = df[['LoadDay','cases','deaths','countriesAndTerritories']]

# %%
ndf
# Out:
#        LoadDay  cases  deaths                     countriesAndTerritories
# 0   2020-03-10     -9       1  Cases_on_an_international_conveyance_Japan
# 1   2020-03-02      0       0  Cases_on_an_international_conveyance_Japan
# 2   2020-03-01      0       0  Cases_on_an_international_conveyance_Japan
# 3   2020-02-29      0       2  Cases_on_an_international_conveyance_Japan
# 4   2020-02-28      0       0  Cases_on_an_international_conveyance_Japan
# ..         ...    ...     ...                                         ...
# 671 2020-01-04      0       0                              United_Kingdom
# 672 2020-01-03      0       0                              United_Kingdom
# 673 2020-01-02      0       0                              United_Kingdom
# 674 2020-01-01      0       0                              United_Kingdom
# 675 2019-12-31      0       0                              United_Kingdom
#
# [676 rows x 4 columns]

# %%
ndf.to_sql('covid19_daily', conn)
